# %% [markdown]
# # Challenge 1

# %%
import json
import requests

# %%
response = requests.get('https://imgs.xkcd.com/comics/greek_letters.png')
file = open("greek_letters.png", "wb")
file.write(response.content)
file.close()
print(file)
# Out:
# <_io.BufferedWriter name='greek_letters.png'>

# %%
response = requests.get('https://imgs.xkcd.com/comics/greek_letters_2x.png')
file = open("greek_letters_2x.png", "wb")
file.write(response.content)
file.close()
print(file)
# Out:
# <_io.BufferedWriter name='greek_letters_2x.png'>

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '393053', 'Server': 'nginx', 'Content-Type': 'image/png', 'Last-Modified': 'Sat, 26 Feb 2022 00:20:56 GMT', 'ETag': '"62197268-5ff5d"', 'Expires': 'Mon, 28 Feb 2022 07:48:14 GMT', 'Cache-Control': 'max-age=300', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 28 Feb 2022 13:17:43 GMT', 'Via': '1.1 varnish', 'Age': '67', 'X-Served-By': 'cache-cdg20753-CDG', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1646054263.486275,VS0,VE1'}

# %%
response.content
# Out:
# b'<html>\r\n<head><title>403 Forbidden</title></head>\r\n<body bgcolor="white">\r\n<center><h1>403 Forbidden</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
response.headers['Expires']
# Out:
# 'Mon, 28 Feb 2022 07:48:14 GMT'

# %%
import requests
import pandas as pd
response = requests.get('https://imgs.xkcd.com/comics/greek_letters.png')
response
# Out:
# <Response [200]>

# %%
#get it via API
receive=requests.get('https://imgs.xkcd.com/comics/greek_letters.png')

# %%
with open(r'C:\Users\Administrateur\Downloads\Image.png', "wb") as f:
    f.write(receive.content)

# %% [markdown]
# # Challenge 2

# %%
ploads = requests.get("https://httpbin.org/get")
ploads.status_code
results=response.json()
print(results)
# Out:
# {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.26.0', 'X-Amzn-Trace-Id': 'Root=1-621ccf94-659fc51e3f37c8e036ad776a'}, 'origin': '195.134.167.217', 'url': 'https://httpbin.org/get'}

# %%
data=pd.DataFrame(results)
print(data)
# Out:
#                  args                                   headers  \
# Accept            NaN                                       */*
# Accept-Encoding   NaN                         gzip, deflate, br
# Host              NaN                               httpbin.org
# User-Agent        NaN                    python-requests/2.26.0
# X-Amzn-Trace-Id   NaN  Root=1-621ccc06-7e4a83684c6df0783b48bb01
#
#                           origin                      url
# Accept           195.134.167.217  https://httpbin.org/get
# Accept-Encoding  195.134.167.217  https://httpbin.org/get
# Host             195.134.167.217  https://httpbin.org/get
# User-Agent       195.134.167.217  https://httpbin.org/get
# X-Amzn-Trace-Id  195.134.167.217  https://httpbin.org/get

# %%
ploads = requests.get("https://httpbin.org/get")
ploads
print(ploads.text)
print(ploads.url)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-621cd14b-61fb6ee15cf343d21ae632c6"
#   },
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/get"
# }
#
# https://httpbin.org/get

# %%
# get information from the website => use 'get'
ploads={'things1':1, 'total':25}
ploads=requests.get("https://httpbin.org/get", params=ploads)
ploads.text
# Out:
# '{\n  "args": {\n    "things1": "1", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.26.0", \n    "X-Amzn-Trace-Id": "Root=1-621cd6ef-3f3d976a4e4a48d31ee57dc5"\n  }, \n  "origin": "195.134.167.217", \n  "url": "https://httpbin.org/get?things1=1&total=25"\n}\n'

# %%
data=pd.DataFrame(ploads)
print(data)
# Out:
#                                                    0
# 0  b'{\n  "args": {\n    "things1": "1", \n    "t...
# 1  b'flate, br", \n    "Host": "httpbin.org", \n ...
# 2  b'3d976a4e4a48d31ee57dc5"\n  }, \n  "origin": ...

# %%
ploads={'Username':'name', 'Password':'adm'}
r=requests.post("https://httpbin.org/post", data=ploads)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "Password": "adm",
#     "Username": "name"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "26",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.26.0",
#     "X-Amzn-Trace-Id": "Root=1-621cd602-397577857eb3f7a06d0567a3"
#   },
#   "json": null,
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# # Challenge 3

# %%
import requests
req_2 = requests.get('https://api.github.com/search/code?q=.scavengerhunt+in:path+repo:ironhack-datalabs/scavenger')
search = req_2.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
import pandas as pd

# %%
results = req_2.json()
flattened_data = pd.json_normalize(results)

req_2.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Tue, 08 Mar 2022 15:00:43 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'no-cache', 'Vary': 'Accept, Accept-Encoding, Accept, X-Requested-With', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-RateLimit-Limit': '10', 'X-RateLimit-Remaining': '9', 'X-Rat
# ...

# %%
data = pd.DataFrame(results['items'])
data_sorted = data.sort_values(by=['name'])
data_sorted
# Out:
#                    name                       path  \
# 10  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 5   .0002.scavengerhunt  88596/.0002.scavengerhunt
# 18  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 21  .0004.scavengerhunt  68848/.0004.scavengerhunt
# 13  .0005.scavengerhunt  44639/.0005.scavengerhunt
# 7   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 17  .0007.scavengerhunt  17020/.0007.scavengerhunt
# 23  .0008.scavengerhunt  15534/.0008.scavengerhunt
# 1   .0009.scavengerhunt  97881/.0009.scavengerhunt
# 20  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 6   .0011.scavengerhunt  50896/.0011.scavengerhunt
# 9   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 12  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 8   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 16  .0015.scavengerhunt  91701/.0015.scavengerhunt
# 0   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 22  .0017.scavengerhunt  70985/.0017.scavengerhunt
# ...

# %%
files = search['items'];
files = sorted(files, key=lambda file: file['name']);
files
# Out:
# [{'name': '.0001.scavengerhunt',
#   'path': '98750/.0001.scavengerhunt',
#   'sha': '2add7632f1323136324efbf38ec66db1838b6173',
#   'url': 'https://api.github.com/repositories/162375181/contents/98750/.0001.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'git_url': 'https://api.github.com/repositories/162375181/git/blobs/2add7632f1323136324efbf38ec66db1838b6173',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750/.0001.scavengerhunt',
#   'repository': {'id': 162375181,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#    'name': 'scavenger',
#    'full_name': 'ironhack-datalabs/scavenger',
#    'private': False,
#    'owner': {'login': 'ironhack-datalabs',
#     'id': 44225188,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ironhack-datalabs',
# ...

# %%
contents_list = []
headers = {'Accept': 'application/vnd.github.v3.raw', };
headers
# Out:
# {'Accept': 'application/vnd.github.v3.raw'}

# %%
#get content per path and combine in one list
for file in files:
    content_path = ('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}').format(file['path']);
    response = requests.get(content_path, headers=headers);
    contents_list.append(response.text)
contents_list
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %%
clean_contents = [word.strip('\n') for word in contents_list]
joke = " ".join(clean_contents)

# %%
joke = ''
for word in joke:
    answer_bytes = word.encode('ascii')
    messegae_bytes =base64.b64decode(answer_bytes)
    message = messegae_bytes.decode('ascii')
    joke += message.strip('\n') + ' '
#print(message)
print(joke)

# %%
#another way
repo_files_names = [item["name"] for item in search["items"]]
repo_files_names.sort()

repo_files_urls = {item["name"]: item["url"] for item in search["items"]}
repo_files_urls
# Out:
# {'.0016.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0009.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/97881/.0009.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0021.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/30351/.0021.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0023.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/55417/.0023.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0019.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/70751/.0019.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#  '.0002.scavengerhunt': 'https://api.github.com/repositories/162375181/contents/88596/.0002.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
# ...

# %%
repo_files = [requests.get(repo_files_urls[repo_filename]) for repo_filename in repo_files_names]
repo_files
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
repo_files_content = [file.json()["content"] for file in repo_files]
repo_files_content
# Out:
# ['SW4K\n',
#  'ZGF0YQo=\n',
#  'c2NpZW5jZSwK\n',
#  'ODAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'c3BlbnQK\n',
#  'aXMK\n',
#  'cHJlcGFyaW5nCg==\n',
#  'ZGF0YSwK\n',
#  'MjAK\n',
#  'cGVyY2VudAo=\n',
#  'b2YK\n',
#  'dGltZQo=\n',
#  'aXMK\n',
#  'c3BlbnQK\n',
#  'Y29tcGxhaW5pbmcK\n',
#  'YWJvdXQK\n',
#  'dGhlCg==\n',
#  'bmVlZAo=\n',
#  'dG8K\n',
#  'cHJlcGFyZQo=\n',
#  'ZGF0YS4K\n']

# %%
import base64

message = [base64.b64decode(b64message).decode('ascii') for b64message in repo_files_content]
message
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %%
joke = ''.join(message).replace('\n', ' ')
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data. '

# %%
#OLD TO KEEP FOR ME

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/forks', auth=('victoirey', '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'));
data = response.json()
data
# Out:
# [{'id': 464851111,
#   'node_id': 'R_kgDOG7UQpw',
#   'name': 'scavenger',
#   'full_name': 'helmichaaba/scavenger',
#   'private': False,
#   'owner': {'login': 'helmichaaba',
#    'id': 98045032,
#    'node_id': 'U_kgDOBdgMaA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/98045032?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/helmichaaba',
#    'html_url': 'https://github.com/helmichaaba',
#    'followers_url': 'https://api.github.com/users/helmichaaba/followers',
#    'following_url': 'https://api.github.com/users/helmichaaba/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/helmichaaba/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/helmichaaba/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/helmichaaba/subscriptions',
#    'organizations_url': 'https://api.github.com/users/helmichaaba/orgs',
#    'repos_url': 'https://api.github.com/users/helmichaaba/repos',
# ...

# %%
#We say that we search for ‘.scavenger’ in the path of the files in the repo IronHack-data labs/scavenger
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
data=pd.DataFrame(search["items"])
data
# Out:
#                    name                       path  \
# 0   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 1   .0009.scavengerhunt  97881/.0009.scavengerhunt
# 2   .0021.scavengerhunt  30351/.0021.scavengerhunt
# 3   .0023.scavengerhunt  55417/.0023.scavengerhunt
# 4   .0019.scavengerhunt  70751/.0019.scavengerhunt
# 5   .0002.scavengerhunt  88596/.0002.scavengerhunt
# 6   .0011.scavengerhunt  50896/.0011.scavengerhunt
# 7   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 8   .0014.scavengerhunt  49418/.0014.scavengerhunt
# 9   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 10  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 11  .0018.scavengerhunt  45525/.0018.scavengerhunt
# 12  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 13  .0005.scavengerhunt  44639/.0005.scavengerhunt
# 14  .0020.scavengerhunt  55685/.0020.scavengerhunt
# 15  .0024.scavengerhunt  47222/.0024.scavengerhunt
# 16  .0015.scavengerhunt  91701/.0015.scavengerhunt
# ...

# %%
sorted(data.name)
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0012.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0024.scavengerhunt']

# %%
sorted(data.html_url)
# Out:
# ['https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15534/.0008.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15534/.0012.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/17020/.0007.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/30351/.0021.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/40303/.0022.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/44639/.0005.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/45525/.0018.scavengerhunt',
# ...

# %%
message_string = ""
for i in data.html_url:
    message = requests.get(i)
    message_string += str(message)
message_string
# Out:
# '<Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]><Response [200]>'

# %%
#Create a variable for the file name
for file in data.name:
    print(file)
# Out:
# .0016.scavengerhunt
# .0009.scavengerhunt
# .0021.scavengerhunt
# .0023.scavengerhunt
# .0019.scavengerhunt
# .0002.scavengerhunt
# .0011.scavengerhunt
# .0006.scavengerhunt
# .0014.scavengerhunt
# .0012.scavengerhunt
# .0001.scavengerhunt
# .0018.scavengerhunt
# .0013.scavengerhunt
# .0005.scavengerhunt
# .0020.scavengerhunt
# .0024.scavengerhunt
# .0015.scavengerhunt
# .0007.scavengerhunt
# .0003.scavengerhunt
# .0022.scavengerhunt
# .0010.scavengerhunt
# .0004.scavengerhunt
# .0017.scavengerhunt
# .0008.scavengerhunt
