# %% [markdown]
# # Understanding Over & Underfitting
# ## Predicting Boston Housing Prices

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %% [markdown]
# ---
# ## Data Exploration
# Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %%
# Your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

boston = pd.read_csv('boston_data.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 1  0.10328  25.0   5.13   0.0  0.453  5.927  47.2  6.9320  8.0  284.0
# 2  0.34940   0.0   9.90   0.0  0.544  5.972  76.7  3.1025  4.0  304.0
# 3  2.73397   0.0  19.58   0.0  0.871  5.597  94.9  1.5257  5.0  403.0
# 4  0.04337  21.0   5.64   0.0  0.439  6.115  63.0  6.8147  4.0  243.0
#
#    ptratio   black  lstat  medv
# 0     19.2  376.94   9.88  21.7
# 1     19.7  396.90   9.22  19.6
# 2     18.4  396.24   9.97  20.3
# 3     14.7  351.85  21.45  15.4
# 4     16.8  393.97   9.43  20.5

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   chas     404 non-null    float64
#  4   nox      404 non-null    float64
#  5   rm       404 non-null    float64
#  6   age      404 non-null    float64
#  7   dis      404 non-null    float64
#  8   rad      404 non-null    float64
#  9   tax      404 non-null    float64
#  10  ptratio  404 non-null    float64
#  11  black    404 non-null    float64
#  12  lstat    404 non-null    float64
#  13  medv     404 non-null    float64
# dtypes: float64(14)
# memory usage: 44.3 KB

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox         rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.00000
# mean     3.730912   10.509901   11.189901    0.069307    0.556710    6.30145
# std      8.943922   22.053733    6.814909    0.254290    0.117321    0.67583
# min      0.006320    0.000000    0.460000    0.000000    0.392000    3.56100
# 25%      0.082382    0.000000    5.190000    0.000000    0.453000    5.90275
# 50%      0.253715    0.000000    9.795000    0.000000    0.538000    6.23050
# 75%      4.053158   12.500000   18.100000    0.000000    0.631000    6.62925
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.78000
#
#               age         dis         rad         tax     ptratio       black  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.601733    3.799666    9.836634  411.688119   18.444554  355.068243
# ...

# %%
boston.chas= np.where(boston.chas == 1, 'true', 'false')
boston.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas        object
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad        float64
# tax        float64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
stats = boston.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#          count        mean         std        min         25%         50%  \
# crim     404.0    3.730912    8.943922    0.00632    0.082382    0.253715
# zn       404.0   10.509901   22.053733    0.00000    0.000000    0.000000
# indus    404.0   11.189901    6.814909    0.46000    5.190000    9.795000
# nox      404.0    0.556710    0.117321    0.39200    0.453000    0.538000
# rm       404.0    6.301450    0.675830    3.56100    5.902750    6.230500
# age      404.0   68.601733   28.066143    2.90000   45.800000   76.600000
# dis      404.0    3.799666    2.109916    1.16910    2.087875    3.207450
# rad      404.0    9.836634    8.834741    1.00000    4.000000    5.000000
# tax      404.0  411.688119  171.073553  187.00000  281.000000  330.000000
# ptratio  404.0   18.444554    2.150295   12.60000   17.375000   19.000000
# black    404.0  355.068243   94.489572    0.32000  374.710000  391.065000
# lstat    404.0   12.598936    6.925173    1.73000    7.135000   11.265000
# ...

# %%
outliers = pd.DataFrame(columns=boston.columns)
 
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = boston[(boston[col] < lower) | 
                   (boston[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
#          crim    zn  indus   chas    nox     rm    age     dis   rad    tax  \
# 8    10.06230   0.0  18.10  false  0.584  6.833   94.3  2.0882  24.0  666.0
# 10   25.94060   0.0  18.10  false  0.679  5.304   89.1  1.6475  24.0  666.0
# 14   15.17720   0.0  18.10  false  0.740  6.152  100.0  1.9142  24.0  666.0
# 17   15.02340   0.0  18.10  false  0.614  5.304   97.3  2.1007  24.0  666.0
# 34   38.35180   0.0  18.10  false  0.693  5.453  100.0  1.4896  24.0  666.0
# ..        ...   ...    ...    ...    ...    ...    ...     ...   ...    ...
# 347   9.23230   0.0  18.10  false  0.631  6.216  100.0  1.1691  24.0  666.0
# 352   2.01019   0.0  19.58  false  0.605  7.929   96.2  2.0459   5.0  403.0
# 382   6.53876   0.0  18.10   true  0.631  7.016   97.5  1.2024  24.0  666.0
# 388   0.33147   0.0   6.20  false  0.507  8.247   70.4  3.6519   8.0  307.0
# 401   0.01501  90.0   1.21   true  0.401  7.923   24.8  5.8850   1.0  198.0
#
#      ptratio   black  lstat  medv Outlier
# ...

# %%
print(len(outliers.index.unique()))
# Out:
# 158

# %%
boston=boston.drop(index=outliers.index)
boston
# Out:
#         crim    zn  indus   chas    nox     rm   age     dis   rad    tax  \
# 0    0.15876   0.0  10.81  false  0.413  5.961  17.5  5.2873   4.0  305.0
# 1    0.10328  25.0   5.13  false  0.453  5.927  47.2  6.9320   8.0  284.0
# 2    0.34940   0.0   9.90  false  0.544  5.972  76.7  3.1025   4.0  304.0
# 3    2.73397   0.0  19.58  false  0.871  5.597  94.9  1.5257   5.0  403.0
# 4    0.04337  21.0   5.64  false  0.439  6.115  63.0  6.8147   4.0  243.0
# ..       ...   ...    ...    ...    ...    ...   ...     ...   ...    ...
# 396  0.06899   0.0  25.65  false  0.581  5.870  69.7  2.2577   2.0  188.0
# 397  0.10084   0.0  10.01  false  0.547  6.715  81.6  2.6775   6.0  432.0
# 398  0.67191   0.0   8.14  false  0.538  5.813  90.3  4.6820   4.0  307.0
# 399  9.32909   0.0  18.10  false  0.713  6.185  98.7  2.2616  24.0  666.0
# 403  0.08244  30.0   4.93  false  0.428  6.481  18.5  6.1899   6.0  300.0
#
#      ptratio   black  lstat  medv
# 0       19.2  376.94   9.88  21.7
# ...

# %% [markdown]
# ### Next, we want to explore the data. Pick several varibables you think will be most correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %%
# Your plots here
corr_var = ['crim', 'lstat', 'rm']

f, axes = plt.subplots(1, len(corr_var), figsize=(15, 10))

for i, f in enumerate(corr_var):
    sns.regplot(x=boston[f], y=boston['medv'], color="b",ax=axes[i])

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?

# %%
# Your response here
# median value decreases as the crim rate increases 
# median value decreases with the lowest status of the population (lowest is the pop status, lowest is the median value)
# median value increases with the number of rooms

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
# Your response here
remaining_var=boston.drop(corr_var, axis=1)

corr = remaining_var.corr().round(2)
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# 1. Dis & nox: weighted mean of distances to five Boston employment centres // nitrogen oxides concentration (parts per 10 million).
# 2. Dis & indus: weighted mean of distances to five Boston employment centres // proportion of non-retail business acres per town.
# 3. Tax & rad: full-value property-tax rate per \$10,000 // index of accessibility to radial highways

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
# Your code here
boston.describe()
# Out:
#              crim          zn       indus         nox          rm         age  \
# count  246.000000  246.000000  246.000000  246.000000  246.000000  246.000000
# mean     1.352420    3.884146   10.883293    0.542052    6.185996   67.167886
# std      2.487150    8.582005    6.307069    0.107413    0.445766   26.651000
# min      0.006320    0.000000    1.380000    0.409000    4.903000    2.900000
# 25%      0.088267    0.000000    5.960000    0.458500    5.885750   48.125000
# 50%      0.180290    0.000000    8.560000    0.520000    6.167000   70.850000
# 75%      0.786055    0.000000   18.100000    0.581000    6.437750   91.175000
# max      9.966540   30.000000   27.740000    0.871000    7.691000  100.000000
#
#               dis         rad         tax     ptratio       black       lstat  \
# count  246.000000  246.000000  246.000000  246.000000  246.000000  246.000000
# mean     3.935714    7.735772  370.711382   18.677642  388.683618   12.256545
# ...

# %%
boston.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas        object
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad        float64
# tax        float64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %%
boston.chas = np.where(boston.chas == 'true', 1, 0)
boston.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int32
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad        float64
# tax        float64
# ptratio    float64
# black      float64
# lstat      float64
# medv       float64
# dtype: object

# %% [markdown]
# ----
#
# ## Developing a Model

# %% [markdown]
# ### Implementation: Define a Performance Metric
# What is the performance meteric with which you will determine the performance of your model? Create a function that calculates this performance metric, and then returns the score.

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    # Your code here:
    return r2_score(y_true, y_predict)

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the traing and test.

# %%
# Your code here
x = boston.drop(['medv'], axis=1)
y = boston['medv']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
# Five separate RFR here with the given max depths
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
train=[]
test=[]
param=range(2,21,2)
for p in param:
    rfr = RandomForestRegressor(max_depth=p, random_state=42)
    rfr.fit(x_train, y_train)
    train.append(rfr.score(x_train,y_train))
    test.append(rfr.score(x_test,y_test))

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
# Produce a plot with the score for the testing and training for the different max depths
plt.plot(param, train)
plt.plot(param, test)

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %% [raw]
# Depth increase lead to improvement in accuracy score of model, stabilized from c. 8

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %% [raw]
# When the model is trained with a maximum depth of 1, the model suffers from high bias (underfit).
# When the model is trained with a maximum depth of 10, the model suffers from high variance (overfit).

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Run your model and explain its performance.

# %%
# Your response here
rfr = RandomForestRegressor(max_depth=8)
rfr.fit(x_train, y_train)
print(rfr.score(x_train, y_train))
# Out:
# 0.9492482870178585

# %% [markdown]
# ### Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %%
# Your response here
